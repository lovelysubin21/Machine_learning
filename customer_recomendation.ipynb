# %%
import pandas as pd

# %%
data =pd.read_csv("D:\python learning\market_data.csv")

# %%
data.head()
# Out:
#   RepName Day of Created_x Customer Type  CustomerId Customer Name  \
# 0   AKASH  11 October 2023         Mason       12082     Saravanan
# 1   AKASH  11 October 2023         Mason       12082     Saravanan
# 2   AKASH  11 October 2023         Mason       12082     Saravanan
# 3   AKASH  11 October 2023         Mason       12082     Saravanan
# 4   AKASH  11 October 2023         Mason       12082     Saravanan
#
#                                        Address 1_x          Area Name  \
# 0  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 1  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 2  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 3  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 4  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
#
#   City Name District_x StateName_x  ... Rep Name  \
# 0   VELLORE    VELLORE  TAMIL NADU  ...    akash
# ...

# %%
data.columns
# Out:
# Index(['RepName', 'Day of Created_x', 'Customer Type', 'CustomerId',
#        'Customer Name', 'Address 1_x', 'Area Name', 'City Name', 'District_x',
#        'StateName_x', 'MobileNumber_x', 'Latlng_x', 'GST No_x', 'DealerId',
#        'RepName_x', 'Day of Created Date', 'City Name_x', 'Area Name_x',
#        'Dealer Name_x', 'Category Name_x', 'Sub-Category_x', 'Brand Name_x',
#        'Dealer type', 'Rank', 'Sourcing Partner', 'SourcingPartnerType',
#        'Credit Status_x', 'RepName_y', 'Day of Created_y', 'Dealer Name_y',
#        'Address 1_y', 'Area Name_y', 'City Name_y', 'District_y',
#        'StateName_y', 'MobileNumber_y', 'Latlng_y', 'Lot Size',
#        'Customer Rating', 'Credit Rating', 'GST No_y', 'SiteId', 'Rep. Name',
#        'Day of Created (sites)', 'Site Name_x', 'Address1 (sites)',
#        'Area/Town', 'CityName', 'District Name_x', 'Pin Code', 'Lat.Lng.',
#        'MobileNo.', 'Initial Construction Stage', 'Rep Name',
# ...

# %%
data[['Day of Created_x','Day of Created Date','Day of Created_y','Day of Created (sites)','Day of Created (sitebrandmixlines)']]
# Out:
#       Day of Created_x Day of Created Date Day of Created_y  \
# 0      11 October 2023      6 October 2023   6 October 2023
# 1      11 October 2023      6 October 2023   6 October 2023
# 2      11 October 2023      6 October 2023   6 October 2023
# 3      11 October 2023      6 October 2023   6 October 2023
# 4      11 October 2023      6 October 2023   6 October 2023
# ...                ...                 ...              ...
# 14100  19 October 2023     19 October 2023  19 October 2023
# 14101  19 October 2023     19 October 2023  19 October 2023
# 14102  19 October 2023     19 October 2023  19 October 2023
# 14103  19 October 2023     19 October 2023  19 October 2023
# 14104  19 October 2023     19 October 2023  19 October 2023
#
#       Day of Created (sites) Day of Created (sitebrandmixlines)
# 0            11 October 2023                    11 October 2023
# 1            11 October 2023                    11 October 2023
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14105 entries, 0 to 14104
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   RepName                             14105 non-null  object
#  1   Day of Created_x                    14105 non-null  object
#  2   Customer Type                       14105 non-null  object
#  3   CustomerId                          14105 non-null  int64
#  4   Customer Name                       14105 non-null  object
#  5   Address 1_x                         14105 non-null  object
#  6   Area Name                           14089 non-null  object
#  7   City Name                           14057 non-null  object
#  8   District_x                          14105 non-null  object
#  9   StateName_x                         13993 non-null  object
#  10  MobileNumber_x                      14105 non-null  object
# ...

# %%
df_1 = data[['CustomerId',"Day of Created Date","Sub-Category_x"]]

# %%
df_1.columns = ["CustomerId","Date","products"]

# %%
df_1
# Out:
#        CustomerId             Date     products
# 0           12082   6 October 2023     TMT BARS
# 1           12082   6 October 2023     TMT BARS
# 2           12082   6 October 2023     TMT BARS
# 3           12082   6 October 2023     TMT BARS
# 4           12082   6 October 2023     TMT BARS
# ...           ...              ...          ...
# 14100       12686  19 October 2023  WATER TANKS
# 14101       12686  19 October 2023  WATER TANKS
# 14102       12686  19 October 2023  WATER TANKS
# 14103       12686  19 October 2023  WATER TANKS
# 14104       12686  19 October 2023  WATER TANKS
#
# [14105 rows x 3 columns]

# %%
df_1["Date"] = pd.to_datetime(df_1['Date'])
# Out:
# C:\Users\SUBIN.S\AppData\Local\Temp\ipykernel_3528\2593280830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1["Date"] = pd.to_datetime(df_1['Date'])

# %%
df_1
# Out:
#        CustomerId       Date     products
# 0           12082 2023-10-06     TMT BARS
# 1           12082 2023-10-06     TMT BARS
# 2           12082 2023-10-06     TMT BARS
# 3           12082 2023-10-06     TMT BARS
# 4           12082 2023-10-06     TMT BARS
# ...           ...        ...          ...
# 14100       12686 2023-10-19  WATER TANKS
# 14101       12686 2023-10-19  WATER TANKS
# 14102       12686 2023-10-19  WATER TANKS
# 14103       12686 2023-10-19  WATER TANKS
# 14104       12686 2023-10-19  WATER TANKS
#
# [14105 rows x 3 columns]

# %%
df_1 = df_1.sort_values(["CustomerId","Date"])

# %%
df_1
# Out:
#        CustomerId       Date            products
# 13141       11883 2023-08-24  SWITCHES & SOCKETS
# 13142       11883 2023-08-24  SWITCHES & SOCKETS
# 13143       11883 2023-08-24  SWITCHES & SOCKETS
# 13144       11883 2023-08-24  SWITCHES & SOCKETS
# 13145       11883 2023-08-24  SWITCHES & SOCKETS
# ...           ...        ...                 ...
# 11888       12711 2023-08-25                 PPC
# 11889       12711 2023-08-25                 PPC
# 11890       12711 2023-10-04               TILES
# 11891       12711 2023-10-04               TILES
# 11892       12711 2023-10-04               TILES
#
# [14105 rows x 3 columns]

# %%
unique_data = df_1.groupby(["CustomerId","Date"])["products"].unique().agg(list).reset_index()
with_duplicate = df_1.groupby(["CustomerId","Date"])["products"].agg(list).reset_index()
# Out:
# C:\Users\SUBIN.S\AppData\Local\Temp\ipykernel_3528\830801320.py:1: FutureWarning: using <class 'list'> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   unique_data = df_1.groupby(["CustomerId","Date"])["products"].unique().agg(list).reset_index()

# %%
unique_data[unique_data["CustomerId"]==11889]
# Out:
#    CustomerId       Date                       products
# 2       11889 2023-08-24  [PPC, BINDING WIRE, TMT BARS]
# 3       11889 2023-10-31                     [TMT BARS]

# %%
unique_data
# Out:
#      CustomerId       Date                                           products
# 0         11883 2023-08-24  [SWITCHES & SOCKETS, WIRES & CABLES, PIPE FITT...
# 1         11885 2023-08-30  [LED, MCB, SWITCHES & SOCKETS, WIRES & CABLES,...
# 2         11889 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 3         11889 2023-10-31                                         [TMT BARS]
# 4         11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 379       12695 2023-10-31                                         [TMT BARS]
# 380       12698 2023-10-09                      [PPC, BINDING WIRE, TMT BARS]
# 381       12711 2023-08-25                                              [PPC]
# 382       12711 2023-10-04                                            [TILES]
#
# [383 rows x 3 columns]

# %%
len(unique_data["CustomerId"].unique())
# Out:
# 246

# %%
df_1.groupby(["CustomerId","Date","products"]).size().reset_index(name="counts").sort_values("counts",ascending=False)
# Out:
#       CustomerId       Date            products  counts
# 909        12519 2023-09-01      WIRES & CABLES     135
# 526        12223 2023-09-01      WIRES & CABLES     108
# 96         11928 2023-09-06  SWITCHES & SOCKETS     104
# 297        12097 2023-09-01      WIRES & CABLES      99
# 311        12099 2023-09-01      WIRES & CABLES      99
# ...          ...        ...                 ...     ...
# 464        12194 2023-09-06         WATER TANKS       2
# 465        12194 2023-09-06     WOODEN FLOORING       2
# 1081       12619 2023-10-09    STRUCTURAL STEEL       2
# 1083       12620 2023-10-09        BINDING WIRE       2
# 144        11999 2023-08-07        BINDING WIRE       2
#
# [1200 rows x 4 columns]

# %%
unique_data
# Out:
#      CustomerId       Date                                           products
# 0         11883 2023-08-24  [SWITCHES & SOCKETS, WIRES & CABLES, PIPE FITT...
# 1         11885 2023-08-30  [LED, MCB, SWITCHES & SOCKETS, WIRES & CABLES,...
# 2         11889 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 3         11889 2023-10-31                                         [TMT BARS]
# 4         11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 379       12695 2023-10-31                                         [TMT BARS]
# 380       12698 2023-10-09                      [PPC, BINDING WIRE, TMT BARS]
# 381       12711 2023-08-25                                              [PPC]
# 382       12711 2023-10-04                                            [TILES]
#
# [383 rows x 3 columns]

# %% [markdown]
# Apriory

# %%
! pip install mlxtend
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\SUBIN.S\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules,fpgrowth

# %%
t_encoder = TransactionEncoder()

# %%
tras_data = t_encoder.fit(unique_data["products"]).transform(unique_data["products"])

# %%
tras_data
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        ...,
#        [False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
t_encoder.columns_
# Out:
# ['ADHESIVE & SEALANT',
#  'BATHROOM ACCESSORIES',
#  'BINDING WIRE',
#  'BULBS',
#  'CONSTRUCTION CHEMICALS',
#  'DRAWERS & CABINET HARDWARE',
#  'ELECTRICAL CONDUITS',
#  'EXTERIOR WALL PAINTS',
#  'FALSE CEILING',
#  'INTERIOR WALL PAINTS',
#  'LED',
#  'LOCKS',
#  'MCB',
#  'OPC',
#  'PIPE FITTINGS',
#  'PIPES',
#  'PIPES & TUBES',
#  'PLYWOOD',
#  'PPC',
#  'PUMPS & MOTORS',
#  'PVC DOORS',
#  'ROOFING SHEETS',
#  'SANITARY WARE',
#  'STRUCTURAL STEEL',
#  'SWITCH GEAR & ACCESSORIES',
#  'SWITCHES & SOCKETS',
#  'TAPS & FAUCETS',
#  'TILES',
#  'TMT BARS',
#  'UNDERCOATS',
#  'WALL PUTTY',
#  'WATER TANKS',
#  'WIRES & CABLES',
#  'WOOD & METAL',
#  'WOOD COATING',
#  'WOODEN DOOR',
#  'WOODEN FLOORING']

# %%
encode_data = pd.DataFrame(tras_data,columns=t_encoder.columns_)

# %%
encode_data
# Out:
#      ADHESIVE & SEALANT  BATHROOM ACCESSORIES  BINDING WIRE  BULBS  \
# 0                 False                 False         False  False
# 1                 False                 False         False  False
# 2                 False                 False          True  False
# 3                 False                 False         False  False
# 4                 False                  True         False   True
# ..                  ...                   ...           ...    ...
# 378               False                 False          True  False
# 379               False                 False         False  False
# 380               False                 False          True  False
# 381               False                 False         False  False
# 382               False                 False         False  False
#
#      CONSTRUCTION CHEMICALS  DRAWERS & CABINET HARDWARE  ELECTRICAL CONDUITS  \
# 0                     False                       False                False
# ...

# %%
apri = apriori(encode_data,min_support=0.159, use_colnames=True)

# %%
association_rules(apri,metric="confidence")
# Out:
#         antecedents     consequents  antecedent support  consequent support  \
# 0    (BINDING WIRE)           (PPC)            0.462141            0.537859
# 1  (ROOFING SHEETS)  (BINDING WIRE)            0.161880            0.462141
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.389034    0.841808  1.565109  0.140467    2.921391       0.671304
# 1  0.161880    1.000000  2.163842  0.087069         inf       0.641745

# %%
# FB -Growth

fpg = fpgrowth(encode_data, min_support=0.059, use_colnames=True)
association_rules(fpg,metric='confidence')
# Out:
#                               antecedents  \
# 0                    (SWITCHES & SOCKETS)
# 1                        (WIRES & CABLES)
# 2                                 (PIPES)
# 3                                 (PIPES)
# 4                                 (PIPES)
# ..                                    ...
# 119  (ROOFING SHEETS, PIPES & TUBES, PPC)
# 120         (BINDING WIRE, PIPES & TUBES)
# 121       (ROOFING SHEETS, PIPES & TUBES)
# 122                  (PIPES & TUBES, PPC)
# 123                       (PIPES & TUBES)
#
#                              consequents  antecedent support  \
# 0                       (WIRES & CABLES)            0.109661
# 1                   (SWITCHES & SOCKETS)            0.107050
# 2                   (SWITCHES & SOCKETS)            0.088773
# 3                       (WIRES & CABLES)            0.088773
# 4                                  (LED)            0.088773
# ..                                   ...                 ...
# ...

# %% [markdown]
# Customer based Recomendation

# %%
df_2 = data[["CustomerId","Day of Created Date", "Sub-Category_x","Credit Rating"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df_2["Credit Rating"] = le.fit_transform(df_2["Credit Rating"])
# Out:
# C:\Users\SUBIN.S\AppData\Local\Temp\ipykernel_3528\4096386686.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2["Credit Rating"] = le.fit_transform(df_2["Credit Rating"])

# %%
df_2
# Out:
#        CustomerId Day of Created Date Sub-Category_x  Credit Rating
# 0           12082      6 October 2023       TMT BARS              5
# 1           12082      6 October 2023       TMT BARS              5
# 2           12082      6 October 2023       TMT BARS              5
# 3           12082      6 October 2023       TMT BARS              5
# 4           12082      6 October 2023       TMT BARS              5
# ...           ...                 ...            ...            ...
# 14100       12686     19 October 2023    WATER TANKS              5
# 14101       12686     19 October 2023    WATER TANKS              5
# 14102       12686     19 October 2023    WATER TANKS              5
# 14103       12686     19 October 2023    WATER TANKS              5
# 14104       12686     19 October 2023    WATER TANKS              5
#
# [14105 rows x 4 columns]

# %%
df_2 = df_2.groupby("CustomerId")["Credit Rating"].sum().reset_index()
df_2
# Out:
#      CustomerId  Credit Rating
# 0         11883            120
# 1         11885            480
# 2         11889             80
# 3         11891           1340
# 4         11892            255
# ..          ...            ...
# 241       12689            120
# 242       12690             60
# 243       12695             80
# 244       12698             60
# 245       12711             45
#
# [246 rows x 2 columns]

# %%
df_2 = df_2.sort_values("CustomerId",ascending=True)

# %%
df = unique_data.sort_values("CustomerId",ascending=True)

# %%
df
# Out:
#      CustomerId       Date                                           products
# 0         11883 2023-08-24  [SWITCHES & SOCKETS, WIRES & CABLES, PIPE FITT...
# 1         11885 2023-08-30  [LED, MCB, SWITCHES & SOCKETS, WIRES & CABLES,...
# 2         11889 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 3         11889 2023-10-31                                         [TMT BARS]
# 4         11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 379       12695 2023-10-31                                         [TMT BARS]
# 380       12698 2023-10-09                      [PPC, BINDING WIRE, TMT BARS]
# 381       12711 2023-08-25                                              [PPC]
# 382       12711 2023-10-04                                            [TILES]
#
# [383 rows x 3 columns]

# %%
df["Rating"] = df_2["Credit Rating"]

# %%
df.head()
# Out:
#    CustomerId       Date                                           products  \
# 0       11883 2023-08-24  [SWITCHES & SOCKETS, WIRES & CABLES, PIPE FITT...
# 1       11885 2023-08-30  [LED, MCB, SWITCHES & SOCKETS, WIRES & CABLES,...
# 2       11889 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 3       11889 2023-10-31                                         [TMT BARS]
# 4       11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
#
#    Rating
# 0   120.0
# 1   480.0
# 2    80.0
# 3  1340.0
# 4   255.0

# %%
df["productsID"] = df["products"].apply(lambda x: hash(tuple(x)))

# %%
df.head()
# Out:
#    CustomerId       Date                                           products  \
# 0       11883 2023-08-24  [SWITCHES & SOCKETS, WIRES & CABLES, PIPE FITT...
# 1       11885 2023-08-30  [LED, MCB, SWITCHES & SOCKETS, WIRES & CABLES,...
# 2       11889 2023-08-24                      [PPC, BINDING WIRE, TMT BARS]
# 3       11889 2023-10-31                                         [TMT BARS]
# 4       11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
#
#    Rating           productsID
# 0   120.0   178290354580603428
# 1   480.0  3867788277567805927
# 2    80.0 -6251355606952066944
# 3  1340.0  -152028895688673774
# 4   255.0 -2629810575942810694

# %% [markdown]
# Installing Surprise

# %%
from surprise import Dataset,Reader, SVD
from surprise.model_selection import train_test_split

# %%
# Reading
readed = Reader(line_format="user item rating",rating_scale=(0,1))

# %%
df.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 383 entries, 0 to 382
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  383 non-null    int64
#  1   Date        383 non-null    datetime64[ns]
#  2   products    383 non-null    object
#  3   Rating      383 non-null    float64
#  4   productsID  383 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 18.0+ KB

# %%
data_for_sur = Dataset.load_from_df(df[["CustomerId","productsID","Rating"]],readed)

# %%
data_for_sur

# %%
train_data, test_data =train_test_split(data_for_sur,test_size=0.2)

# %%
data
# Out:
#       RepName Day of Created_x Customer Type  CustomerId  \
# 0       AKASH  11 October 2023         Mason       12082
# 1       AKASH  11 October 2023         Mason       12082
# 2       AKASH  11 October 2023         Mason       12082
# 3       AKASH  11 October 2023         Mason       12082
# 4       AKASH  11 October 2023         Mason       12082
# ...       ...              ...           ...         ...
# 14100  VENKAT  19 October 2023         Mason       12686
# 14101  VENKAT  19 October 2023         Mason       12686
# 14102  VENKAT  19 October 2023         Mason       12686
# 14103  VENKAT  19 October 2023         Mason       12686
# 14104  VENKAT  19 October 2023         Mason       12686
#
#                           Customer Name  \
# 0                             Saravanan
# 1                             Saravanan
# 2                             Saravanan
# 3                             Saravanan
# 4                             Saravanan
# ...

# %%
model = SVD()

# %%
model.fit(train_data)

# %%
from itertools import chain

# %%
def show_recom(cust_id,number_of_rec):
    products_overall = df["productsID"].unique()
    procust_bought =df[df["CustomerId"]==cust_id]["productsID"].values
    prod_used_for_predict = [i for i in products_overall if i not in procust_bought]
    predict_recom = [(prod, model.predict(cust_id,prod).est) for prod in prod_used_for_predict]

    output_recom = [df[df["productsID"]== i_d]["products"].values[0] for i_d, a in predict_recom[:number_of_rec]]
    out_list = list(chain.from_iterable(output_recom))
    out_list = list(set(out_list))
    return out_list

# %%
df[df["CustomerId"]==11891]
# Out:
#    CustomerId       Date                                           products  \
# 4       11891 2023-09-01  [BULBS, ELECTRICAL CONDUITS, LED, MCB, SWITCH ...
# 5       11891 2023-09-06  [PPC, SANITARY WARE, BINDING WIRE, TMT BARS, I...
# 6       11891 2023-10-09                             [INTERIOR WALL PAINTS]
#
#    Rating           productsID
# 4   255.0 -2629810575942810694
# 5   480.0 -8515587394498327400
# 6    80.0  2132809661652787859

# %%
show_recom(11891,2)
# Out:
# ['WATER TANKS',
#  'PIPE FITTINGS',
#  'WIRES & CABLES',
#  'SWITCHES & SOCKETS',
#  'MCB',
#  'LED',
#  'INTERIOR WALL PAINTS',
#  'WOOD & METAL',
#  'PIPES',
#  'EXTERIOR WALL PAINTS']

# %%
products_overall = df["productsID"].unique()
procust_bounght = df[df["CustomerId"]==18891]["productsID"].values

# %%
for i in procust_bounght:
    print(i)

# %%
prod_used_for_predict = [i for i in products_overall if i not in procust_bounght]

# %%
predict_recom = [(prod, model.predict(11891,prod).est) for prod in prod_used_for_predict]

# %%
for prod in prod_used_for_predict:
    print(model.predict("AZZZMSZI9LKE6",prod))
# Out:
# user: AZZZMSZI9LKE6 item: 178290354580603428 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: 3867788277567805927 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: -6251355606952066944 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: -152028895688673774 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: -2629810575942810694 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: -8515587394498327400 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: 2132809661652787859 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: -8279064881684034598 r_ui = None   est = 1.00   {'was_impossible': False}
# user: AZZZMSZI9LKE6 item: 1283634980869770379 r_ui = None   est = 1.00   {'was_impossible': False}
# ...

# %%
predict_recom
# Out:
# [(178290354580603428, 1),
#  (3867788277567805927, 1),
#  (-6251355606952066944, 1),
#  (-152028895688673774, 1),
#  (-2629810575942810694, 1),
#  (-8515587394498327400, 1),
#  (2132809661652787859, 1),
#  (-8279064881684034598, 1),
#  (1283634980869770379, 1),
#  (-2249920340649816174, 1),
#  (3879308631617738511, 1),
#  (-7210445955271899722, 1),
#  (8073927429678494825, 1),
#  (6769009037329222851, 1),
#  (-8880432687744752449, 1),
#  (-4781815470360532638, 1),
#  (-285947317432616681, 1),
#  (-4340806533517138200, 1),
#  (-2967179105994242083, 1),
#  (-4698023847935292010, 1),
#  (-286989986626704512, 1),
#  (7658915045401615882, 1),
#  (-3331340043982607783, 1),
#  (1525585921794985315, 1),
#  (2569808482157400492, 1),
#  (-6029286902114567719, 1),
#  (-902731326297224862, 1),
#  (7662502300353789787, 1),
#  (-6112169845253416764, 1),
#  (5256200302855545231, 1),
#  (-6412092730048145507, 1),
#  (-5724294902449335344, 1),
#  (-2891247163233383354, 1),
# ...

# %%
output_recom = [df[df["productsID"]== i_d]["products"].values[0] for i_d, a in predict_recom[:3]]
out_list = list(chain.from_iterable(output_recom))
out_list= list(set(out_list))
out_list
# Out:
# ['BINDING WIRE',
#  'WATER TANKS',
#  'PIPE FITTINGS',
#  'PPC',
#  'WIRES & CABLES',
#  'TMT BARS',
#  'SWITCHES & SOCKETS',
#  'MCB',
#  'LED',
#  'INTERIOR WALL PAINTS',
#  'WOOD & METAL',
#  'PIPES',
#  'EXTERIOR WALL PAINTS']
