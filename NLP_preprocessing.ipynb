# %%
! pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\SUBIN.S\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\SUBIN.S\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import re #regular Expression
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
sample_text="""In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."""

# %%
sample_text = sample_text.lower()
sample_text
# Out:
# "in a world where data reigns supreme,a numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. with a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 sustainable development goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the
# ...

# %%
sample_tokens = word_tokenize(sample_text)
sample_tokens
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %%
import pickle
with open("sample_tokens.pkl","wb") as mf:
    pickle.dump(sample_tokens,mf)

# %% [markdown]
# stopwords removal

# %%
type(stopwords.words("english"))
# Out:
# list

# %%
stop_words = stopwords.words('english')
stop_words = set(stop_words)

# %%
sr_list = []
for i in sample_tokens:
    if i not in stop_words:
        print(i)
        sr_list.append(i)
# Out:
# world
# data
# reigns
# supreme
# ,
# numbers
# paint
# vivid
# picture
# reality
# ,
# serving
# foundation
# upon
# build
# understanding
# world
# .
# population
# 7.9
# billion
# souls
# populating
# planet
# ,
# digit
# represents
# life
# unique
# story
# ,
# struggles
# ,
# aspirations
# .
# yet
# ,
# amidst
# vastness
# humanity
# ,
# digital
# realm
# equally
# expansive
# ,
# staggering
# 2.5
# quintillion
# bytes
# data
# generated
# daily
# ,
# fueling
# engines
# innovation
# ,
# commerce
# ,
# communication
# .
# within
# digital
# landscape
# ,
# certain
# numerical
# values
# stand
# beacons
# significance
# :
# 2030
# sustainable
# development
# goals
# ,
# set
# 17
# ambitious
# objectives
# aiming
# eradicate
# poverty
# ,
# reduce
# inequality
# ,
# combat
# climate
# change
# ,
# symbolizing
# humanity
# 's
# collective
# aspirations
# better
# tomorrow
# .
# meanwhile
# ,
# $
# 2.7
# trillion
# global
# e-commerce
# market
# continues
# reshape
# future
# ...

# %%
sr_list = [i for i in sample_tokens if i not in stop_words]

# %%
sr_list
# Out:
# ['world',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'numbers',
#  'paint',
#  'vivid',
#  'picture',
#  'reality',
#  ',',
#  'serving',
#  'foundation',
#  'upon',
#  'build',
#  'understanding',
#  'world',
#  '.',
#  'population',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'planet',
#  ',',
#  'digit',
#  'represents',
#  'life',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'vastness',
#  'humanity',
#  ',',
#  'digital',
#  'realm',
#  'equally',
#  'expansive',
#  ',',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'engines',
#  'innovation',
#  ',',
#  'commerce',
#  ',',
#  'communication',
#  '.',
#  'within',
#  'digital',
#  'landscape',
#  ',',
#  'certain',
#  'numerical',
#  'values',
#  'stand',
#  'beacons',
#  'significance',
#  ':',
#  '2030',
#  'sustainable',
#  'development',
#  'goals',
#  ',',
# ...

# %%
sample_tokens
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %% [markdown]
# Number Removal

# %%
input_string = ' '.join(sr_list)

# %%
re.sub(r'\d+', ' ',input_string)
# Out:
# "world data reigns supreme , numbers paint vivid picture reality , serving foundation upon build understanding world . population  .  billion souls populating planet , digit represents life unique story , struggles , aspirations . yet , amidst vastness humanity , digital realm equally expansive , staggering  .  quintillion bytes data generated daily , fueling engines innovation , commerce , communication . within digital landscape , certain numerical values stand beacons significance :   sustainable development goals , set   ambitious objectives aiming eradicate poverty , reduce inequality , combat climate change , symbolizing humanity 's collective aspirations better tomorrow . meanwhile , $  .  trillion global e-commerce market continues reshape future commerce , driving unprecedented levels convenience connectivity across globe . however , amidst triumphs advancements , challenges persist , evidenced  .  million deaths attributed cardiovascular diseases annually , underscoring urg
# ...

# %% [markdown]
# spl Char Removal % punctations

# %%
std_tokens = ['in',
 'a',
 'world',
 'where',
 'data',
 'reigns',
 'supreme',
 ',',
 'a',
 'numbers',
 'paint',
 'a',
 'vivid',
 'picture',
 'of',
 'our',
 'reality',
 ',',
 'serving',
 'as',
 'the',
 'foundation',
 'upon',
 'which',
 'we',
 'build',
 'our',
 'understanding',
 'of',
 'the',
 'world',
 '.',
 'with',
 'a',
 'population',
 'of',
 '7.9',
 'billion',
 'souls',
 'populating',
 'our',
 'planet',
 ',',
 'each',
 'digit',
 'represents',
 'a',
 'life',
 'with',
 'its',
 'own',
 'unique',
 'story',
 ',',
 'struggles',
 ',',
 'and',
 'aspirations',
 '.',
 'yet',
 ',',
 'amidst',
 'the',
 'vastness',
 'of',
 'humanity',
 ',',
 'the',
 'digital',
 'realm',
 'is',
 'equally',
 'expansive',
 ',',
 'with',
 'a',
 'staggering',
 '2.5',
 'quintillion',
 'bytes',
 'of',
 'data',
 'generated',
 'daily',
 ',',
 'fueling',
 'the',
 'engines',
 'of',
 'innovation',
 ',',
 'commerce',
 ',',
 'and',
 'communication',
 '.',
 'within',
 'this',
 'digital',
 'landscape',
 ',',
 'certain',
 'numerical',
 'values',
 'stand',
 'out',
 'as',
 'beacons',
 'of',
 'significance',
 ':',
 'the',
 '2030',
 'sustainable',
 'development',
 'goals',
 ',',
 'a',
 'set',
 'of',
 '17',
 'ambitious',
 'objectives',
 'aiming',
 'to',
 'eradicate',
 'poverty',
 ',',
 'reduce',
 'inequality',
 ',',
 'and',
 'combat',
 'climate',
 'change',
 ',',
 'symbolizing',
 'humanity',
 "'s",
 'collective',
 'aspirations',
 'for',
 'a',
 'better',
 'tomorrow',
 '.',
 'meanwhile',
 ',',
 'the',
 '$',
 '2.7',
 'trillion',
 'global',
 'e-commerce',
 'market',
 'continues',
 'to',
 'reshape',
 'the',
 'future',
 'of',
 'commerce',
 ',',
 'driving',
 'unprecedented',
 'levels',
 'of',
 'convenience',
 'and',
 'connectivity',
 'across',
 'the',
 'globe',
 '.',
 'however',
 ',',
 'amidst',
 'the',
 'triumphs',
 'and',
 'advancements',
 ',',
 'challenges',
 'persist',
 ',',
 'as',
 'evidenced',
 'by',
 'the',
 '17.1',
 'million',
 'deaths',
 'attributed',
 'to',
 'cardiovascular',
 'diseases',
 'annually',
 ',',
 'underscoring',
 'the',
 'urgent',
 'need',
 'for',
 'healthcare',
 'innovation',
 'and',
 'preventative',
 'measures',
 '.',
 'in',
 'every',
 'digit',
 ',',
 'from',
 'the',
 'billions',
 'of',
 'people',
 'to',
 'the',
 'trillions',
 'of',
 'dollars',
 ',',
 'lies',
 'a',
 'story',
 'waiting',
 'to',
 'be',
 'told',
 ',',
 'a',
 'problem',
 'waiting',
 'to',
 'be',
 'solved',
 ',',
 'and',
 'a',
 'future',
 'waiting',
 'to',
 'be',
 'shaped',
 'by',
 'the',
 'collective',
 'efforts',
 'of',
 'humanity',
 '.']

# %%
[re.sub(r'[^a-zA-Z0-9]','', i ) for i in std_tokens]
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  '',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  '',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '',
#  'with',
#  'a',
#  'population',
#  'of',
#  '79',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  '',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  '',
#  'struggles',
#  '',
#  'and',
#  'aspirations',
#  '',
#  'yet',
#  '',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  '',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  '',
#  'with',
#  'a',
#  'staggering',
#  '25',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  '',
#  'fueling',
#  'the',
#  'engines',
# ...

# %%
[re.sub(r'\w+', '', i) for i in std_tokens]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  ',',
#  '',
#  '',
#  '.',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  ',',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  '',
#  '',
#  ',',
#  '',
#  '',
#  "'",
# ...

# %% [markdown]
# Spell Ckecking

# %%
! pip install pyspellchecker
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\SUBIN.S\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from spellchecker import SpellChecker

# %%
checker = SpellChecker()

# %%
[checker.correction(i) for i in std_tokens]
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %% [markdown]
# Streamming

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
stemmer = PorterStemmer()

# %%
std_tokens
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %% [markdown]
# Lemmatizer

# %%
lemm = WordNetLemmatizer()

# %%
std_tokens
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'a',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %%
[lemm.lemmatize(i) for i in std_tokens]
# Out:
# ['in',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reign',
#  'supreme',
#  ',',
#  'a',
#  'number',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'a',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'with',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'soul',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'it',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggle',
#  ',',
#  'and',
#  'aspiration',
#  '.',
#  'yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'byte',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %% [markdown]
# POS

# %%
import nltk

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\SUBIN.S\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
input_sent = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
tokens = nltk.word_tokenize(input_sent)

# %%
tokens
# Out:
# ['In',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'A',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'With',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'Yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %%
pos_tagged_words = nltk.pos_tag(tokens)

# %%
noun_list = []
non_noun = []
for i,j in pos_tagged_words:
    if j not in ['PRP','NN']:
        print(i)
        non_noun.append(i)
    else:
        print(i)
        noun_list.append(i)
# Out:
# In
# a
# world
# where
# data
# reigns
# supreme
# ,
# A
# numbers
# paint
# a
# vivid
# picture
# of
# our
# reality
# ,
# serving
# as
# the
# foundation
# upon
# which
# we
# build
# our
# understanding
# of
# the
# world
# .
# With
# a
# population
# of
# 7.9
# billion
# souls
# populating
# our
# planet
# ,
# each
# digit
# represents
# a
# life
# with
# its
# own
# unique
# story
# ,
# struggles
# ,
# and
# aspirations
# .
# Yet
# ,
# amidst
# the
# vastness
# of
# humanity
# ,
# the
# digital
# realm
# is
# equally
# expansive
# ,
# with
# a
# staggering
# 2.5
# quintillion
# bytes
# of
# data
# generated
# daily
# ,
# fueling
# the
# engines
# of
# innovation
# ,
# commerce
# ,
# and
# communication
# .
# Within
# this
# digital
# landscape
# ,
# certain
# numerical
# values
# stand
# out
# as
# beacons
# of
# significance
# :
# the
# 2030
# Sustainable
# Development
# Goals
# ,
# a
# set
# of
# 17
# ambitious
# objectives
# aiming
# to
# eradicate
# poverty
# ,
# reduce
# ...

# %% [markdown]
# N grams

# %%
from nltk.util import ngrams

# %%
input_text = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
input_text
tokens = word_tokenize(input_text)

# %%
len(tokens)
# Out:
# 253

# %%
ngrams(tokens,2)

# %%
gram_2 = list(ngrams(tokens,2))

# %%
gram_2
# Out:
# [('In', 'a'),
#  ('a', 'world'),
#  ('world', 'where'),
#  ('where', 'data'),
#  ('data', 'reigns'),
#  ('reigns', 'supreme'),
#  ('supreme', ','),
#  (',', 'A'),
#  ('A', 'numbers'),
#  ('numbers', 'paint'),
#  ('paint', 'a'),
#  ('a', 'vivid'),
#  ('vivid', 'picture'),
#  ('picture', 'of'),
#  ('of', 'our'),
#  ('our', 'reality'),
#  ('reality', ','),
#  (',', 'serving'),
#  ('serving', 'as'),
#  ('as', 'the'),
#  ('the', 'foundation'),
#  ('foundation', 'upon'),
#  ('upon', 'which'),
#  ('which', 'we'),
#  ('we', 'build'),
#  ('build', 'our'),
#  ('our', 'understanding'),
#  ('understanding', 'of'),
#  ('of', 'the'),
#  ('the', 'world'),
#  ('world', '.'),
#  ('.', 'With'),
#  ('With', 'a'),
#  ('a', 'population'),
#  ('population', 'of'),
#  ('of', '7.9'),
#  ('7.9', 'billion'),
#  ('billion', 'souls'),
#  ('souls', 'populating'),
#  ('populating', 'our'),
#  ('our', 'planet'),
#  ('planet', ','),
#  (',', 'each'),
#  ('each', 'digit'),
#  ('digit', 'represents'),
# ...

# %%
gram_3 = list(ngrams(tokens,3))

# %%
gram_3
# Out:
# [('In', 'a', 'world'),
#  ('a', 'world', 'where'),
#  ('world', 'where', 'data'),
#  ('where', 'data', 'reigns'),
#  ('data', 'reigns', 'supreme'),
#  ('reigns', 'supreme', ','),
#  ('supreme', ',', 'A'),
#  (',', 'A', 'numbers'),
#  ('A', 'numbers', 'paint'),
#  ('numbers', 'paint', 'a'),
#  ('paint', 'a', 'vivid'),
#  ('a', 'vivid', 'picture'),
#  ('vivid', 'picture', 'of'),
#  ('picture', 'of', 'our'),
#  ('of', 'our', 'reality'),
#  ('our', 'reality', ','),
#  ('reality', ',', 'serving'),
#  (',', 'serving', 'as'),
#  ('serving', 'as', 'the'),
#  ('as', 'the', 'foundation'),
#  ('the', 'foundation', 'upon'),
#  ('foundation', 'upon', 'which'),
#  ('upon', 'which', 'we'),
#  ('which', 'we', 'build'),
#  ('we', 'build', 'our'),
#  ('build', 'our', 'understanding'),
#  ('our', 'understanding', 'of'),
#  ('understanding', 'of', 'the'),
#  ('of', 'the', 'world'),
#  ('the', 'world', '.'),
#  ('world', '.', 'With'),
#  ('.', 'With', 'a'),
#  ('With', 'a', 'population'),
# ...

# %% [markdown]
# Tokenization

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sample_text = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
word_tokenize(sample_text)
# Out:
# ['In',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'A',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'With',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'Yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %%
tokens = word_tokenize(sample_text)

# %%
tokens
# Out:
# ['In',
#  'a',
#  'world',
#  'where',
#  'data',
#  'reigns',
#  'supreme',
#  ',',
#  'A',
#  'numbers',
#  'paint',
#  'a',
#  'vivid',
#  'picture',
#  'of',
#  'our',
#  'reality',
#  ',',
#  'serving',
#  'as',
#  'the',
#  'foundation',
#  'upon',
#  'which',
#  'we',
#  'build',
#  'our',
#  'understanding',
#  'of',
#  'the',
#  'world',
#  '.',
#  'With',
#  'a',
#  'population',
#  'of',
#  '7.9',
#  'billion',
#  'souls',
#  'populating',
#  'our',
#  'planet',
#  ',',
#  'each',
#  'digit',
#  'represents',
#  'a',
#  'life',
#  'with',
#  'its',
#  'own',
#  'unique',
#  'story',
#  ',',
#  'struggles',
#  ',',
#  'and',
#  'aspirations',
#  '.',
#  'Yet',
#  ',',
#  'amidst',
#  'the',
#  'vastness',
#  'of',
#  'humanity',
#  ',',
#  'the',
#  'digital',
#  'realm',
#  'is',
#  'equally',
#  'expansive',
#  ',',
#  'with',
#  'a',
#  'staggering',
#  '2.5',
#  'quintillion',
#  'bytes',
#  'of',
#  'data',
#  'generated',
#  'daily',
#  ',',
#  'fueling',
#  'the',
# ...

# %%
sent_tokenize(sample_text)
# Out:
# ['In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world.',
#  'With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations.',
#  'Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication.',
#  "Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow.",
# ...

# %%
" ".join(tokens)
# Out:
# "In a world where data reigns supreme , A numbers paint a vivid picture of our reality , serving as the foundation upon which we build our understanding of the world . With a population of 7.9 billion souls populating our planet , each digit represents a life with its own unique story , struggles , and aspirations . Yet , amidst the vastness of humanity , the digital realm is equally expansive , with a staggering 2.5 quintillion bytes of data generated daily , fueling the engines of innovation , commerce , and communication . Within this digital landscape , certain numerical values stand out as beacons of significance : the 2030 Sustainable Development Goals , a set of 17 ambitious objectives aiming to eradicate poverty , reduce inequality , and combat climate change , symbolizing humanity 's collective aspirations for a better tomorrow . Meanwhile , the $ 2.7 trillion global e-commerce market continues to reshape the future of commerce , driving unprecedented levels of convenience a
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfTransformer #term frequency
from sklearn.metrics import classification_report

# %% [markdown]
# Sentiment Analysis

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sent = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
sent
# Out:
# "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the
# ...

# %%
sent_ment = SentimentIntensityAnalyzer()

# %%
sent_score = sent_ment.polarity_scores(sent)

# %%
sent_score
# Out:
# {'neg': 0.06, 'neu': 0.826, 'pos': 0.114, 'compound': 0.8625}

# %%
sent_score['compound']
# Out:
# 0.8625

# %% [markdown]
# word Clood

# %%
! pip install WordCloud
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: C:\Users\SUBIN.S\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
w_c = WordCloud(width=1000, height=500, background_color="gold").generate(sent)

plt.figure(figsize=(14,6))
plt.imshow(w_c)
plt.axis('off')
plt.show()

# %%
w_c

# %% [markdown]
# Keyword extraction

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
input_text = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
vect = CountVectorizer(stop_words="english")

# %%
ext_val = vect.fit_transform([input_text])

# %%
vect.get_feature_names_out()
# Out:
# array(['17', '2030', 'advancements', 'aiming', 'ambitious', 'amidst',
#        'annually', 'aspirations', 'attributed', 'beacons', 'better',
#        'billion', 'billions', 'build', 'bytes', 'cardiovascular',
#        'certain', 'challenges', 'change', 'climate', 'collective',
#        'combat', 'commerce', 'communication', 'connectivity', 'continues',
#        'convenience', 'daily', 'data', 'deaths', 'development', 'digit',
#        'digital', 'diseases', 'dollars', 'driving', 'efforts', 'engines',
#        'equally', 'eradicate', 'evidenced', 'expansive', 'foundation',
#        'fueling', 'future', 'generated', 'global', 'globe', 'goals',
#        'healthcare', 'humanity', 'inequality', 'innovation', 'landscape',
#        'levels', 'lies', 'life', 'market', 'measures', 'million', 'need',
#        'numbers', 'numerical', 'objectives', 'paint', 'people', 'persist',
#        'picture', 'planet', 'populating', 'population', 'poverty',
# ...

# %%
import spacy

# %%
# load spacy English language model
nlp = spacy.load("en_core_web_sm")

# %%
# sample text for NER
text = "In a world where data reigns supreme,A numbers paint a vivid picture of our reality, serving as the foundation upon which we build our understanding of the world. With a population of 7.9 billion souls populating our planet, each digit represents a life with its own unique story, struggles, and aspirations. Yet, amidst the vastness of humanity, the digital realm is equally expansive, with a staggering 2.5 quintillion bytes of data generated daily, fueling the engines of innovation, commerce, and communication. Within this digital landscape, certain numerical values stand out as beacons of significance: the 2030 Sustainable Development Goals, a set of 17 ambitious objectives aiming to eradicate poverty, reduce inequality, and combat climate change, symbolizing humanity's collective aspirations for a better tomorrow. Meanwhile, the $2.7 trillion global e-commerce market continues to reshape the future of commerce, driving unprecedented levels of convenience and connectivity across the globe. However, amidst the triumphs and advancements, challenges persist, as evidenced by the 17.1 million deaths attributed to cardiovascular diseases annually, underscoring the urgent need for healthcare innovation and preventative measures. In every digit, from the billions of people to the trillions of dollars, lies a story waiting to be told, a problem waiting to be solved, and a future waiting to be shaped by the collective efforts of humanity."

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(f"Entity: {ent.text}, type: {ent.label_}")
# Out:
# Entity: supreme, type: ORG
# Entity: 7.9 billion, type: CARDINAL
# Entity: 2.5, type: CARDINAL
# Entity: daily, type: DATE
# Entity: 2030, type: DATE
# Entity: 17, type: CARDINAL
# Entity: tomorrow, type: DATE
# Entity: $2.7 trillion, type: MONEY
# Entity: the 17.1 million, type: CARDINAL
# Entity: annually, type: DATE
# Entity: billions, type: CARDINAL
# Entity: the trillions of dollars, type: MONEY
